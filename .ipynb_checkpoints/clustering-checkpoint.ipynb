# %%
import pandas as pd
import openai
import re
from sentence_transformers import SentenceTransformer
import torch
import sys

print(sys.executable)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9

# %%
df = pd.read_csv('narc.csv')
moas = df['MoA']

# %%
# !{sys.executable} -m pip install sentence-transformers
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
openai.api_key = "" # vedant key 
def parse(answer):
    print("hi")
    question = "given some examples, identify the receptor type and binding mode that come before the mechanism of action. answer n/a if not specified."
    prompt = "Example: the receptors are: histamine h3. the subtypes are: n/a. the binding modes are: inverse agonist. therefore the mechanism of action is: selective histamine h3 receptor inverse agonist. additionally, modafinil is a wakefulnesspromoting agent.\n"
    prompt += "Answer: histamine h3 receptor inverse agonist\n"
    prompt += "Example: the receptors are: dopamine. the subtypes are: not specified in the abstract. the binding modes are: agonist. therefore the mechanism of action is: dopamine agonist.\n"
    prompt += "Answer: dopamine agonist"
    prompt += "the mechanism of action is: putative central alpha1 agonist. however, the article does not mention any specific receptor subtypes that the drug modafinil is being evaluated with.\n"
    prompt += "Answer: putative cnetral alpha1 agonist"
    prompt += "Example: {}\n".format(answer)
    prompt += "Answer: "
    
    try:
        response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                {"role": "system", "content": "You are a very helpful medical researcher."},
                {"role": "user", "content": prompt}]
        )
        text = response['choices'][0]['message']['content']
    except:
        print("Error")
        text = "None"
    return text
        
def get_MoA(answer):
    answer = answer.lower()
    answer = answer.replace("(", "")
    answer = answer.replace(")", "")
    answer = answer.replace("-", "")
    answer = answer.replace("\\", " ")
    
    parsed_answer = parse(answer)
    print("Bayus")
    parsed_answer = parsed_answer.lower()
    parsed_answer = parsed_answer.replace("(", "")
    parsed_answer = parsed_answer.replace(")", "")
    parsed_answer = parsed_answer.replace("-", " ")
    parsed_answer = parsed_answer.replace("\\", " ")

    print(parsed_answer)
    return parsed_answer

# %%
cook_moa = []
for moa in moas:
    cook_moa += [get_MoA(moa)]
# Out:
# hi
# Bayus
# selective histamine h3 receptor inverse agonist
# hi
# Bayus
# there is no information given to provide an example.
# hi
# Bayus
# histamine3 receptor inverse agonist
# hi
# Bayus
# selective histamine 3 h3 antagonist/inverse agonist.
# hi
# Bayus
# histamine h3 receptor inverse agonist
# hi
# Bayus
# h3 antagonist/inverse agonist
# hi
# Bayus
# gabab agonist
# hi
# Bayus
# n/a not specified.
# hi
# Bayus
# selective histamine 3 receptor antagonist/inverse agonist.
# hi
# Bayus
# histamine h3 receptor inverse agonist   pitolisant
# hi
# Bayus
# putative central alpha1 agonist
# hi
# Bayus
# gaba agonist specifically gabab receptor agonist and/or ghb receptor agonist.
# hi
# Bayus
# ghb/gabab receptor agonist
# hi
# Bayus
# gaba agonist
# hi
# Bayus
# dopamine d2 receptor agonist.
# hi
# Bayus
# ghb/gammaaminobutyric acid b receptor agonist
# hi
# Bayus
# n/a not applicable as there is no information provided about the binding modes.
# hi
# Bayus
# ...

# %%
print(cook_moa)
# Out:
# ['selective histamine h3 receptor inverse agonist', 'there is no information given to provide an example.', 'histamine3 receptor inverse agonist', 'selective histamine 3 h3 antagonist/inverse agonist.', 'histamine h3 receptor inverse agonist', 'h3 antagonist/inverse agonist', 'gabab agonist', 'n/a not specified.', 'selective histamine 3 receptor antagonist/inverse agonist.', 'histamine h3 receptor inverse agonist   pitolisant', 'putative central alpha1 agonist', 'gaba agonist specifically gabab receptor agonist and/or ghb receptor agonist.', 'ghb/gabab receptor agonist', 'gaba agonist', 'dopamine d2 receptor agonist.', 'ghb/gammaaminobutyric acid b receptor agonist', 'n/a not applicable as there is no information provided about the binding modes.', 'histamine h3 receptor inverse agonist.', 'gaba receptor agonist', 'ghb/gabab receptor agonist.', 'dopamine agonist', 'no specific mechanism of action or receptor subtype mentioned.', 'gabab receptor agonists/pharmacology', 'dual orexin re
# ...

# %%
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

sentence1 = ['histamine H5 receptor antagonist']
sentence2 = ['serotonin-5-HT1A receptor partial agonist']
sentence3 = ['histamine H5 receptor']

embedding1 = torch.from_numpy(model.encode(sentence1))
embedding2 = torch.from_numpy(model.encode(sentence2))
embedding3 = torch.from_numpy(model.encode(sentence3))

print(embedding1, embedding2)

cos = torch.nn.CosineSimilarity(dim=1, eps=1e-6)

print(cos(embedding1, embedding2), cos(embedding2, embedding3), cos(embedding1, embedding3))
# Out:
# tensor([[-1.2869e-01, -3.1490e-01, -1.8536e-01, -3.6028e-01,  6.9757e-02,
#          -6.0819e-02,  4.4758e-01,  2.4126e-01, -4.6531e-01, -3.7491e-01,
#          -6.9673e-02, -2.2717e-01, -2.4573e-01,  5.3794e-01,  3.0837e-03,
#          -4.5915e-01,  4.8488e-01,  1.8270e-01,  2.0694e-02, -3.1753e-02,
#          -3.8422e-01,  8.6955e-01, -3.7452e-02, -3.6183e-01, -2.0668e-01,
#          -2.5598e-01,  5.0823e-01, -3.8904e-01, -5.8430e-01, -1.5492e-01,
#           2.3613e-01,  6.0958e-02,  4.5978e-02, -6.3792e-01, -2.3208e-01,
#          -4.3157e-01, -2.8791e-01, -8.1075e-02, -7.9761e-02, -3.8459e-01,
#          -2.9928e-01,  5.4298e-01, -2.0128e-01,  4.4757e-01, -4.1069e-03,
#           1.4170e-01, -2.5504e-01, -3.6366e-01,  2.8574e-01,  7.6042e-01,
#           4.4507e-03, -3.6205e-01,  3.3727e-02,  2.6197e-01,  6.6345e-02,
#          -1.5012e-01, -6.9741e-01,  4.4046e-01, -5.2889e-01,  4.6590e-01,
#          -5.9348e-01,  4.6951e-01,  2.6011e-01, -1.3229e-02,  6.5644e-01,
# ...

# %%
def get_similarity(a, b):
    embedding_a = torch.from_numpy(model.encode([a]))
    embedding_b = torch.from_numpy(model.encode([b]))
    return cos(embedding_a, embedding_b)

def contains(array, query_string):
    for val in array:
        if query_string.find(val) >= 0:
            return True
    return False
# TODO look into another model like ChemBERT and see how to classify weird outputs as weird
# Maybe just check if agonist/inverse / etc. is present or not in the word! that would be very easy and i think it works.....
def cluster_stuff(MoA_list):
    clusters = {'n/a not specified': []} 
    not_found = ['n/a', 'no', 'there', 'specified', 'information', 'mentioned']
    threshold = 0.7 # have to hyerparameter tune this
    num = 0
    for ele in MoA_list:
        num += 1
        if contains(not_found, ele):
            clusters['n/a not specified'].append(ele)
            continue
        best = 0.0
        cluster_to_match = ""
        for compare_cluster in clusters:
            if get_similarity(compare_cluster, ele) > best:
                best = get_similarity(compare_cluster, ele)
                cluster_to_match = compare_cluster
        if best > threshold:
            clusters[cluster_to_match].append(ele)
        else:
            clusters[ele] = [ele]
        print(num)
    print(len(clusters))
    return clusters

# %%
clusters = cluster_stuff(cook_moa)
# Out:
# 1
# 3
# 4
# 5
# 6
# 7
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# 18
# 19
# 20
# 21
# 23
# 24
# 25
# 26
# 27
# 29
# 30
# 31
# 36
# 44
# 65
# 73
# 81
# 96
# 101
# 110
# 117
# 121
# 122
# 129
# 132
# 133
# 138
# 143
# 146
# 147
# 151
# 152
# 153
# 155
# 17

# %%
# Post process clusters
for key in clusters:
    print(key)
    print(clusters[key])
# Out:
# n/a not specified
# ...
